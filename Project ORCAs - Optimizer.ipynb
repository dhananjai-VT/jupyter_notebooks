# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import pickle
import sqlalchemy as sa
import datetime as dtt
import calendar

from subject_query import subject_query
from schedule_query import schedule_query
from appointments_today import upcoming_appointments_today

from ortools.linear_solver import pywraplp
import nest_asyncio

# %%
# list of reps and subjects for which we want to do assignments. In future we will open it for all core
sub_list_csv = """'HS Test Prep','Grade K-6','Grad TP','HS/Col STEM','Other Foreign Lang','Branded','Enrichment','Spanish'"""
rep_list_csv = """'Amanda Newton',
'Emily Cox',
'April Banadonna',
'Courtney Hoitt',
'Bryce Schwanke',
'Brian Kabat',
'Kevin Taulman',
'Kimberly Murdock',
'Gretchen Siegfried',
'Brad DiBello',
'Rosidalma Houston',
'Rachel Brown',
'JoAnn Barghout',
'Jason Hamor',
'Jasmine Lynch',
'Melissa Steinberg',
'Alexander Mayfield',
'Jeanne Bessler',
'Davelle Gilliland',
'Yeneisy Pineiro',
'Yago Lupi'
"""

# connection strings for redshift
connstr = 'redshift+psycopg2://xxx:yyyy@tyson.bi.varsitytutors.com:5439/varsitytutors'
engine = sa.create_engine(connstr, connect_args={'sslmode': 'verify-ca'})

#load data
with engine.connect() as conn, conn.begin():
    df_categories = pd.read_sql(sa.text(subject_query.format(sub_list = sub_list_csv)), conn)
    df_schedules = pd.read_sql(sa.text(schedule_query.format(rep_list = rep_list_csv)), conn)
    df_appointments = pd.read_sql(sa.text(upcoming_appointments_today), conn)
    
total_appointments = len(df_categories.contact_id.unique())

# %%
df_schedules['start_date'] = pd.to_datetime(df_schedules.schedule_start_time).dt.normalize()

#creating a dataframe of 15 min interval to join appoitnment data - this should match with the frequency of appointments
# this is done because scheduled callbacks are set for 15 min block intervals
dti = pd.Series(pd.date_range(start=np.datetime64('today'), periods=96, freq="15min") , name='interval').to_frame()
dti['start_date'] = pd.to_datetime(dti.interval).dt.normalize()

df_schedules_final = pd.merge(dti,df_schedules,on=['start_date'],how='left')
df_schedules_final = df_schedules_final[(df_schedules_final.schedule_start_time <= df_schedules_final.interval) &\
                            (df_schedules_final.schedule_end_time > df_schedules_final.interval)].sort_values(by=['mgr_name','interval']).reset_index(drop=True)

# %%
# https://varsitytutors.looker.com/looks/10803
# manually overriding the queried appointments_today with the data from here for more realtime data as this looker queries replica
#df_appointments = pd.read_csv("Open todos - user id - for scheduling 2021-02-08T1025.csv")
df_appointments['interval'] = pd.to_datetime(df_appointments.interval)

# %%
df_available_slots = pd.merge(df_schedules_final , df_appointments , on = ['interval' , 'user_id'], how='left')
df_available_slots['is_available'] = np.where(df_available_slots.preassigned_todo_id.isna(),1,0)

# %%
#load rep_tscvr
df_rep_tscvr = pd.read_csv("consultant_sub_tscvr_vals.csv")


# creating value scorecard
df_rep_tscvr['rep_tscvr'] = df_rep_tscvr.closed_client_count/df_rep_tscvr.cc90_count
df_rep_tscvr.sort_values(by = ['subject_group','rep_tscvr'] , ascending = [True,False] , inplace=True)

df_sub_tscvr = df_rep_tscvr.groupby('subject_group').agg(perc_25=pd.NamedAgg(column="rep_tscvr", aggfunc=lambda x: np.percentile(x,25)),
                                          perc_75=pd.NamedAgg(column="rep_tscvr", aggfunc=lambda x: np.percentile(x,75)),
                                          perc_50=pd.NamedAgg(column="rep_tscvr", aggfunc=lambda x: np.percentile(x,50))).reset_index()

df_tscvr_range = pd.merge(df_rep_tscvr,df_sub_tscvr, on = ['subject_group'],how='left')

df_tscvr_range['tscvr_spread'] = df_tscvr_range.rep_tscvr-df_tscvr_range.perc_50

# %%
df_merged = pd.merge(df_categories,df_available_slots,left_on='callback_at_time', right_on='interval',how='left')
df_merged_available = df_merged[df_merged.is_available==1]

total_assignable_appointments = len(df_merged_available.contact_id.unique())
print("Out of {initial} appointments, we have availability for {final} appointments".format(initial=total_appointments , final=total_assignable_appointments))

df_mega = pd.merge(df_merged_available , df_tscvr_range , on =['subject_group','mgr_id','mgr_name'] , how='left')
# Out:
# Out of 248 appointments, we have availability for 241 appointments

# %%
df_final = df_mega[['contact_id', 'contact_created_date', 'subject_group', 'callback_todo_id', 'adword_subject_type_2',
       'callback_at_time', 'tags_name', 'interval', 'mgr_name',
        'mgr_id', 'user_id', 'schedule_start_time',
       'schedule_end_time', 'is_available',
       'rep_tscvr', 'perc_50', 'tscvr_spread']]

df_final = df_final.sort_values(by=['perc_50','callback_todo_id','tscvr_spread'], ascending=[False,True,False])
df_final = df_final[df_final.tscvr_spread>0].reset_index(drop=True)

df_final_assigned = df_available_slots.drop_duplicates().reset_index(drop=True).copy()

# %%
def optimizer(slot, def_matrix):

    list_consultants = def_matrix.mgr_name.unique()
    list_contacts = def_matrix.contact_id.unique()
    df_payout = pd.pivot_table(def_matrix, index='mgr_name', columns='contact_id',values='rep_tscvr',fill_value=-1)
    payout = (np.round(df_payout.stack()*10000,0)).to_dict()
    df_assignability = pd.pivot_table(def_matrix, index='mgr_name', columns='contact_id',values='is_available',fill_value=0)
    assignability = df_assignability.stack().to_dict()


    # Constraints

    solver = pywraplp.Solver.CreateSolver('SCIP')

    x = {}
    for consultant in list_consultants:
        for lead in list_contacts:
            x[consultant, lead] = solver.IntVar(0, 1, '')

    # Each consultant is assigned max 1 todo. 
    # We can potentially change this to 3 max -> the avg connect rate is 30% so this will ensure at least 1 gets connected
    # But need to understand the tradeoff for having the others delayedd if the first one gets connected
    for consultant in list_consultants:
        solver.Add(solver.Sum([x[consultant, lead] for lead in list_contacts]) <= 1)

    # Each todo is assigned to max one consultant or skipped
    for lead in list_contacts:
        solver.Add(solver.Sum([x[consultant, lead] for consultant in list_consultants]) <= 1)

    # Consultants that cannot be assigned the leads
    for consultant in list_consultants:
        for lead in list_contacts:
            if (assignability[consultant,lead]==0):
                solver.Add(x[consultant,lead]==0)

    # Define objective. In this case it is to maximise the tSCVR
    objective_terms = []
    for consultant in list_consultants:
        for lead in list_contacts:
            objective_terms.append(payout[consultant,lead] * x[consultant,lead])
    solver.Maximize(solver.Sum(objective_terms))


    # Solve
    status = solver.Solve()

    # Print solution
    optimized_assignments = []
    assigned_work = []
    if (status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE):
        print('Total optimised tSCVR = ', solver.Objective().Value()/(len(list_contacts)*10000))
        for consultant in list_consultants:
            for lead in list_contacts:
                # Test if x[i,j] is 1 (with tolerance for floating point arithmetic).
                if (x[consultant,lead].solution_value() > 0.5):
                    print('  -> Consultant {c} assigned to lead {l} with expected tSCVR = {p}'.format(c=consultant,l=lead,p=payout[consultant,lead]/10000))
                    optimized_assignments.append([slot,consultant,lead])
                    assigned_work.append(lead)
    else:
        print("Infeasible solution")
        
    unassigned_assignments = np.setdiff1d(list_contacts,assigned_work).tolist()
    
    return(optimized_assignments,unassigned_assignments)

# %%
optimal_list = []
unassigned_leads = []

for slot in np.sort(df_final.interval.unique()):
    def_matrix = df_final[df_final.interval==slot].drop_duplicates().reset_index(drop=True)
    print("\nWe have {unique_todos} appointments at slot {time} and {reps} agents to fill".format(unique_todos = len(def_matrix.callback_todo_id.unique()),
                                                                                          time = slot,
                                                                                           reps= len(def_matrix.mgr_name.unique())))
    optimal, unassigned = optimizer(slot, def_matrix)
    optimal_list.extend(optimal)
    unassigned_leads.extend(unassigned)
    
df_opt_assignment = pd.DataFrame(optimal_list, columns = ['interval','mgr_name', 'assigned_contact']).sort_values(by='interval', ascending=True).reset_index(drop=True)
# Out:
# We have 3 appointments at slot 2021-02-08T07:15:00.000000000 and 2 agents to fill
# Total optimised tSCVR =  0.1826
#   -> Consultant Brian Kabat assigned to lead 4903994 with expected tSCVR = 0.3256
#   -> Consultant Kimberly Murdock assigned to lead 4904151 with expected tSCVR = 0.2222
#
# We have 2 appointments at slot 2021-02-08T07:45:00.000000000 and 3 agents to fill
# Total optimised tSCVR =  0.21995
#   -> Consultant Brian Kabat assigned to lead 4453403 with expected tSCVR = 0.3256
#   -> Consultant Kimberly Murdock assigned to lead 4905551 with expected tSCVR = 0.1143
#
# We have 7 appointments at slot 2021-02-08T08:00:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.2679285714285714
#   -> Consultant Rosidalma Houston assigned to lead 4902212 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4902857 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4897895 with expected tSCVR = 0.3043
#   -> Consultant Kimberly Murdock assigned to lead 4891894 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4906686 with expected tSCVR = 0.3171
#   -> Consultant Jason Hamor assigned to lead 4902863 with expected tSCVR = 0.2405
#
# We have 3 appointments at slot 2021-02-08T08:15:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.28673333333333334
#   -> Consultant Rosidalma Houston assigned to lead 4904606 with expected tSCVR = 0.3835
#   -> Consultant Rachel Brown assigned to lead 4904536 with expected tSCVR = 0.3043
#   -> Consultant Jason Hamor assigned to lead 4905194 with expected tSCVR = 0.1724
#
# We have 4 appointments at slot 2021-02-08T08:30:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.31415
#   -> Consultant Rosidalma Houston assigned to lead 4904748 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4903540 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905109 with expected tSCVR = 0.3043
#   -> Consultant Gretchen Siegfried assigned to lead 4902872 with expected tSCVR = 0.3171
#
# We have 4 appointments at slot 2021-02-08T08:45:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.31744999999999995
#   -> Consultant Rosidalma Houston assigned to lead 4906286 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4905477 with expected tSCVR = 0.3333
#   -> Consultant Kimberly Murdock assigned to lead 4904233 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4906437 with expected tSCVR = 0.2562
#
# We have 4 appointments at slot 2021-02-08T09:00:00.000000000 and 5 agents to fill
# Total optimised tSCVR =  0.25475
#   -> Consultant Gretchen Siegfried assigned to lead 4903927 with expected tSCVR = 0.3171
#   -> Consultant Jason Hamor assigned to lead 4901879 with expected tSCVR = 0.2452
#   -> Consultant Rosidalma Houston assigned to lead 4903584 with expected tSCVR = 0.2294
#   -> Consultant Jeanne Bessler assigned to lead 4904175 with expected tSCVR = 0.2273
#
# We have 10 appointments at slot 2021-02-08T09:15:00.000000000 and 4 agents to fill
# Total optimised tSCVR =  0.13404
#   -> Consultant Rosidalma Houston assigned to lead 4904892 with expected tSCVR = 0.3835
#   -> Consultant Jeanne Bessler assigned to lead 4904535 with expected tSCVR = 0.3333
#   -> Consultant Kimberly Murdock assigned to lead 4904058 with expected tSCVR = 0.3784
#   -> Consultant Jason Hamor assigned to lead 4905761 with expected tSCVR = 0.2452
#
# We have 6 appointments at slot 2021-02-08T09:30:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.30878333333333335
#   -> Consultant Jason Hamor assigned to lead 4904261 with expected tSCVR = 0.4348
#   -> Consultant Rosidalma Houston assigned to lead 4904314 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4904331 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4904571 with expected tSCVR = 0.3043
#   -> Consultant Kimberly Murdock assigned to lead 4904767 with expected tSCVR = 0.2222
#   -> Consultant Gretchen Siegfried assigned to lead 4904952 with expected tSCVR = 0.2562
#
# We have 7 appointments at slot 2021-02-08T09:45:00.000000000 and 5 agents to fill
# Total optimised tSCVR =  0.19058571428571427
#   -> Consultant Rosidalma Houston assigned to lead 4905227 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4907107 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905850 with expected tSCVR = 0.3043
#   -> Consultant Kimberly Murdock assigned to lead 4906556 with expected tSCVR = 0.2222
#   -> Consultant Jason Hamor assigned to lead 4907105 with expected tSCVR = 0.1724
#
# We have 8 appointments at slot 2021-02-08T10:00:00.000000000 and 7 agents to fill
# Total optimised tSCVR =  0.2849375
#   -> Consultant Rosidalma Houston assigned to lead 4894425 with expected tSCVR = 0.3835
#   -> Consultant Jeanne Bessler assigned to lead 4903275 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4903290 with expected tSCVR = 0.3043
#   -> Consultant Kimberly Murdock assigned to lead 4903020 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4903680 with expected tSCVR = 0.2562
#   -> Consultant Yago Lupi assigned to lead 4903883 with expected tSCVR = 0.3182
#   -> Consultant Kevin Taulman assigned to lead 4901761 with expected tSCVR = 0.3056
#
# We have 7 appointments at slot 2021-02-08T10:15:00.000000000 and 8 agents to fill
# Total optimised tSCVR =  0.26124285714285717
#   -> Consultant Rosidalma Houston assigned to lead 4905982 with expected tSCVR = 0.3835
#   -> Consultant Rachel Brown assigned to lead 4902555 with expected tSCVR = 0.1864
#   -> Consultant JoAnn Barghout assigned to lead 4905520 with expected tSCVR = 0.175
#   -> Consultant April Banadonna assigned to lead 4905989 with expected tSCVR = 0.2846
#   -> Consultant Kimberly Murdock assigned to lead 4906600 with expected tSCVR = 0.2222
#   -> Consultant Gretchen Siegfried assigned to lead 4905531 with expected tSCVR = 0.2588
#   -> Consultant Yago Lupi assigned to lead 4904234 with expected tSCVR = 0.3182
#
# We have 7 appointments at slot 2021-02-08T10:30:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.29725714285714283
#   -> Consultant Rosidalma Houston assigned to lead 4902026 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4904859 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4861849 with expected tSCVR = 0.3178
#   -> Consultant JoAnn Barghout assigned to lead 4902960 with expected tSCVR = 0.175
#   -> Consultant Kimberly Murdock assigned to lead 4907388 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4907263 with expected tSCVR = 0.2562
#   -> Consultant Yago Lupi assigned to lead 4902201 with expected tSCVR = 0.3182
#
# We have 4 appointments at slot 2021-02-08T10:45:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.31415
#   -> Consultant Kimberly Murdock assigned to lead 4906469 with expected tSCVR = 0.3784
#   -> Consultant Yago Lupi assigned to lead 4856632 with expected tSCVR = 0.3182
#   -> Consultant JoAnn Barghout assigned to lead 4907696 with expected tSCVR = 0.2581
#   -> Consultant Rosidalma Houston assigned to lead 4904679 with expected tSCVR = 0.3019
#
# We have 2 appointments at slot 2021-02-08T11:00:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.25985
#   -> Consultant Jeanne Bessler assigned to lead 4894364 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4901881 with expected tSCVR = 0.1864
#
# We have 7 appointments at slot 2021-02-08T11:15:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.28441428571428573
#   -> Consultant Rosidalma Houston assigned to lead 4905518 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4907406 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905914 with expected tSCVR = 0.1864
#   -> Consultant Courtney Hoitt assigned to lead 4904372 with expected tSCVR = 0.2955
#   -> Consultant Yago Lupi assigned to lead 4906220 with expected tSCVR = 0.3182
#   -> Consultant Melissa Steinberg assigned to lead 4901286 with expected tSCVR = 0.25
#   -> Consultant Kevin Taulman assigned to lead 4907364 with expected tSCVR = 0.3056
#
# We have 7 appointments at slot 2021-02-08T11:30:00.000000000 and 12 agents to fill
# Total optimised tSCVR =  0.3027285714285714
#   -> Consultant Kimberly Murdock assigned to lead 4906449 with expected tSCVR = 0.3784
#   -> Consultant Brian Kabat assigned to lead 4904297 with expected tSCVR = 0.3047
#   -> Consultant Yago Lupi assigned to lead 4904056 with expected tSCVR = 0.2661
#   -> Consultant JoAnn Barghout assigned to lead 4904480 with expected tSCVR = 0.2581
#   -> Consultant Rosidalma Houston assigned to lead 4903982 with expected tSCVR = 0.3019
#   -> Consultant Rachel Brown assigned to lead 4905525 with expected tSCVR = 0.3043
#   -> Consultant Kevin Taulman assigned to lead 4906986 with expected tSCVR = 0.3056
#
# We have 3 appointments at slot 2021-02-08T11:45:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.3161
#   -> Consultant Rosidalma Houston assigned to lead 4907702 with expected tSCVR = 0.3835
#   -> Consultant Rachel Brown assigned to lead 4906503 with expected tSCVR = 0.1864
#   -> Consultant Kimberly Murdock assigned to lead 4907115 with expected tSCVR = 0.3784
#
# We have 4 appointments at slot 2021-02-08T12:00:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.27825
#   -> Consultant Brian Kabat assigned to lead 4888869 with expected tSCVR = 0.4035
#   -> Consultant Bryce Schwanke assigned to lead 4888718 with expected tSCVR = 0.2174
#   -> Consultant Gretchen Siegfried assigned to lead 4903586 with expected tSCVR = 0.3171
#   -> Consultant JoAnn Barghout assigned to lead 4902063 with expected tSCVR = 0.175
#
# We have 6 appointments at slot 2021-02-08T12:15:00.000000000 and 13 agents to fill
# Total optimised tSCVR =  0.32083333333333336
#   -> Consultant Kimberly Murdock assigned to lead 4907705 with expected tSCVR = 0.3784
#   -> Consultant Brian Kabat assigned to lead 4906635 with expected tSCVR = 0.4035
#   -> Consultant Yago Lupi assigned to lead 4907400 with expected tSCVR = 0.3182
#   -> Consultant Bryce Schwanke assigned to lead 4905643 with expected tSCVR = 0.2174
#   -> Consultant Rosidalma Houston assigned to lead 4906614 with expected tSCVR = 0.3019
#   -> Consultant Kevin Taulman assigned to lead 4904324 with expected tSCVR = 0.3056
#
# We have 12 appointments at slot 2021-02-08T12:30:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.27168333333333333
#   -> Consultant Yago Lupi assigned to lead 4905962 with expected tSCVR = 0.3182
#   -> Consultant Yeneisy Pineiro assigned to lead 4905815 with expected tSCVR = 0.55
#   -> Consultant Courtney Hoitt assigned to lead 4895703 with expected tSCVR = 0.2955
#   -> Consultant JoAnn Barghout assigned to lead 4902298 with expected tSCVR = 0.175
#   -> Consultant Melissa Steinberg assigned to lead 4905762 with expected tSCVR = 0.25
#   -> Consultant Kevin Taulman assigned to lead 4906485 with expected tSCVR = 0.3056
#   -> Consultant April Banadonna assigned to lead 4906336 with expected tSCVR = 0.1412
#   -> Consultant Kimberly Murdock assigned to lead 4891615 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4906306 with expected tSCVR = 0.3171
#   -> Consultant Rosidalma Houston assigned to lead 4905594 with expected tSCVR = 0.3019
#   -> Consultant Jeanne Bessler assigned to lead 4906359 with expected tSCVR = 0.2273
#
# We have 1 appointments at slot 2021-02-08T12:45:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.3784
#   -> Consultant Kimberly Murdock assigned to lead 4906613 with expected tSCVR = 0.3784
#
# We have 7 appointments at slot 2021-02-08T13:00:00.000000000 and 12 agents to fill
# Total optimised tSCVR =  0.30738571428571426
#   -> Consultant Bryce Schwanke assigned to lead 4901808 with expected tSCVR = 0.3571
#   -> Consultant Rachel Brown assigned to lead 4904131 with expected tSCVR = 0.3178
#   -> Consultant Alexander Mayfield assigned to lead 4903758 with expected tSCVR = 0.2131
#   -> Consultant Kimberly Murdock assigned to lead 4905078 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4903091 with expected tSCVR = 0.3171
#   -> Consultant Yago Lupi assigned to lead 4904187 with expected tSCVR = 0.3182
#   -> Consultant Melissa Steinberg assigned to lead 4901892 with expected tSCVR = 0.25
#
# We have 4 appointments at slot 2021-02-08T13:15:00.000000000 and 13 agents to fill
# Total optimised tSCVR =  0.361825
#   -> Consultant Yago Lupi assigned to lead 4903503 with expected tSCVR = 0.6
#   -> Consultant Bryce Schwanke assigned to lead 4907285 with expected tSCVR = 0.2174
#   -> Consultant Brian Kabat assigned to lead 4904391 with expected tSCVR = 0.3256
#   -> Consultant Rachel Brown assigned to lead 4902030 with expected tSCVR = 0.3043
#
# We have 5 appointments at slot 2021-02-08T13:30:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.3066
#   -> Consultant Kimberly Murdock assigned to lead 4906742 with expected tSCVR = 0.3784
#   -> Consultant Yago Lupi assigned to lead 4903807 with expected tSCVR = 0.3182
#   -> Consultant Gretchen Siegfried assigned to lead 4903688 with expected tSCVR = 0.3171
#   -> Consultant Bryce Schwanke assigned to lead 4906521 with expected tSCVR = 0.2174
#   -> Consultant Rosidalma Houston assigned to lead 4905328 with expected tSCVR = 0.3019
#
# We have 2 appointments at slot 2021-02-08T13:45:00.000000000 and 13 agents to fill
# Total optimised tSCVR =  0.2715
#   -> Consultant Brian Kabat assigned to lead 4902158 with expected tSCVR = 0.3256
#   -> Consultant Bryce Schwanke assigned to lead 4907633 with expected tSCVR = 0.2174
#
# We have 9 appointments at slot 2021-02-08T14:00:00.000000000 and 14 agents to fill
# Total optimised tSCVR =  0.32033333333333336
#   -> Consultant Rosidalma Houston assigned to lead 4904251 with expected tSCVR = 0.3835
#   -> Consultant Bryce Schwanke assigned to lead 4904205 with expected tSCVR = 0.3425
#   -> Consultant Brian Kabat assigned to lead 4905321 with expected tSCVR = 0.4035
#   -> Consultant Jeanne Bessler assigned to lead 4904108 with expected tSCVR = 0.2295
#   -> Consultant Rachel Brown assigned to lead 4906387 with expected tSCVR = 0.3043
#   -> Consultant JoAnn Barghout assigned to lead 4881763 with expected tSCVR = 0.2581
#   -> Consultant Kimberly Murdock assigned to lead 4906546 with expected tSCVR = 0.3784
#   -> Consultant Gretchen Siegfried assigned to lead 4905185 with expected tSCVR = 0.3171
#   -> Consultant Yago Lupi assigned to lead 4903632 with expected tSCVR = 0.2661
#
# We have 1 appointments at slot 2021-02-08T14:15:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.3056
#   -> Consultant Kevin Taulman assigned to lead 4907638 with expected tSCVR = 0.3056
#
# We have 4 appointments at slot 2021-02-08T14:30:00.000000000 and 11 agents to fill
# Total optimised tSCVR =  0.31685
#   -> Consultant Kimberly Murdock assigned to lead 4907144 with expected tSCVR = 0.3784
#   -> Consultant Brian Kabat assigned to lead 4906295 with expected tSCVR = 0.3256
#   -> Consultant Yago Lupi assigned to lead 4905051 with expected tSCVR = 0.3182
#   -> Consultant Jason Hamor assigned to lead 4904938 with expected tSCVR = 0.2452
#
# We have 2 appointments at slot 2021-02-08T14:45:00.000000000 and 16 agents to fill
# Total optimised tSCVR =  0.34455
#   -> Consultant Rosidalma Houston assigned to lead 4902534 with expected tSCVR = 0.3835
#   -> Consultant Kevin Taulman assigned to lead 4903508 with expected tSCVR = 0.3056
#
# We have 10 appointments at slot 2021-02-08T15:00:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.29211000000000004
#   -> Consultant Rosidalma Houston assigned to lead 4905172 with expected tSCVR = 0.3835
#   -> Consultant Bryce Schwanke assigned to lead 4902491 with expected tSCVR = 0.3425
#   -> Consultant Brian Kabat assigned to lead 4905854 with expected tSCVR = 0.4035
#   -> Consultant Jeanne Bessler assigned to lead 4902308 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905826 with expected tSCVR = 0.3043
#   -> Consultant Alexander Mayfield assigned to lead 4904875 with expected tSCVR = 0.2131
#   -> Consultant Gretchen Siegfried assigned to lead 4901659 with expected tSCVR = 0.3171
#   -> Consultant Yago Lupi assigned to lead 4905886 with expected tSCVR = 0.3182
#   -> Consultant Kevin Taulman assigned to lead 4901987 with expected tSCVR = 0.3056
#
# We have 4 appointments at slot 2021-02-08T15:15:00.000000000 and 8 agents to fill
# Total optimised tSCVR =  0.31085
#   -> Consultant Brian Kabat assigned to lead 4904644 with expected tSCVR = 0.4035
#   -> Consultant Bryce Schwanke assigned to lead 4907310 with expected tSCVR = 0.2174
#   -> Consultant Rachel Brown assigned to lead 4907093 with expected tSCVR = 0.3043
#   -> Consultant Yago Lupi assigned to lead 4906760 with expected tSCVR = 0.3182
#
# We have 5 appointments at slot 2021-02-08T15:30:00.000000000 and 7 agents to fill
# Total optimised tSCVR =  0.27124
#   -> Consultant Yago Lupi assigned to lead 4902251 with expected tSCVR = 0.3182
#   -> Consultant Rosidalma Houston assigned to lead 4903280 with expected tSCVR = 0.3019
#   -> Consultant Bryce Schwanke assigned to lead 4891715 with expected tSCVR = 0.2174
#   -> Consultant Alexander Mayfield assigned to lead 4904907 with expected tSCVR = 0.2131
#   -> Consultant Kevin Taulman assigned to lead 4904323 with expected tSCVR = 0.3056
#
# We have 2 appointments at slot 2021-02-08T15:45:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.30045
#   -> Consultant Rosidalma Houston assigned to lead 4904762 with expected tSCVR = 0.3835
#   -> Consultant Bryce Schwanke assigned to lead 4906723 with expected tSCVR = 0.2174
#
# We have 9 appointments at slot 2021-02-08T16:00:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.26534444444444444
#   -> Consultant Rosidalma Houston assigned to lead 4905638 with expected tSCVR = 0.3019
#   -> Consultant Bryce Schwanke assigned to lead 4905364 with expected tSCVR = 0.3571
#   -> Consultant Jeanne Bessler assigned to lead 4904503 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905381 with expected tSCVR = 0.2326
#   -> Consultant JoAnn Barghout assigned to lead 4901893 with expected tSCVR = 0.2581
#   -> Consultant April Banadonna assigned to lead 4905390 with expected tSCVR = 0.2139
#   -> Consultant Yeneisy Pineiro assigned to lead 4902214 with expected tSCVR = 0.2063
#   -> Consultant Courtney Hoitt assigned to lead 4905365 with expected tSCVR = 0.1667
#   -> Consultant Yago Lupi assigned to lead 4905190 with expected tSCVR = 0.3182
#
# We have 5 appointments at slot 2021-02-08T16:15:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.28253999999999996
#   -> Consultant Yago Lupi assigned to lead 4897570 with expected tSCVR = 0.3182
#   -> Consultant JoAnn Barghout assigned to lead 4904960 with expected tSCVR = 0.2581
#   -> Consultant Gretchen Siegfried assigned to lead 4892840 with expected tSCVR = 0.3171
#   -> Consultant Bryce Schwanke assigned to lead 4905406 with expected tSCVR = 0.2174
#   -> Consultant Rosidalma Houston assigned to lead 4905852 with expected tSCVR = 0.3019
#
# We have 7 appointments at slot 2021-02-08T16:30:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.2627285714285714
#   -> Consultant Rosidalma Houston assigned to lead 4903991 with expected tSCVR = 0.3835
#   -> Consultant Brian Kabat assigned to lead 4904609 with expected tSCVR = 0.4035
#   -> Consultant Jeanne Bessler assigned to lead 4904789 with expected tSCVR = 0.2295
#   -> Consultant Rachel Brown assigned to lead 4904624 with expected tSCVR = 0.3043
#   -> Consultant April Banadonna assigned to lead 4903279 with expected tSCVR = 0.2143
#   -> Consultant Courtney Hoitt assigned to lead 4906152 with expected tSCVR = 0.1316
#   -> Consultant Jason Hamor assigned to lead 4905769 with expected tSCVR = 0.1724
#
# We have 13 appointments at slot 2021-02-08T17:00:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.2171846153846154
#   -> Consultant Brian Kabat assigned to lead 4905430 with expected tSCVR = 0.3256
#   -> Consultant Jeanne Bessler assigned to lead 4903504 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4905378 with expected tSCVR = 0.2326
#   -> Consultant JoAnn Barghout assigned to lead 4904537 with expected tSCVR = 0.2973
#   -> Consultant April Banadonna assigned to lead 4907002 with expected tSCVR = 0.2846
#   -> Consultant Yeneisy Pineiro assigned to lead 4904301 with expected tSCVR = 0.2537
#   -> Consultant Courtney Hoitt assigned to lead 4906028 with expected tSCVR = 0.2955
#   -> Consultant Jason Hamor assigned to lead 4904961 with expected tSCVR = 0.2452
#   -> Consultant Melissa Steinberg assigned to lead 4898575 with expected tSCVR = 0.25
#   -> Consultant Kevin Taulman assigned to lead 4905241 with expected tSCVR = 0.3056
#
# We have 3 appointments at slot 2021-02-08T17:30:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.30306666666666665
#   -> Consultant Jeanne Bessler assigned to lead 4901748 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4903860 with expected tSCVR = 0.3178
#   -> Consultant JoAnn Barghout assigned to lead 4905211 with expected tSCVR = 0.2581
#
# We have 2 appointments at slot 2021-02-08T17:45:00.000000000 and 10 agents to fill
# Total optimised tSCVR =  0.3045
#   -> Consultant Brian Kabat assigned to lead 4902911 with expected tSCVR = 0.3047
#   -> Consultant Rachel Brown assigned to lead 4904542 with expected tSCVR = 0.3043
#
# We have 5 appointments at slot 2021-02-08T18:00:00.000000000 and 7 agents to fill
# Total optimised tSCVR =  0.28888
#   -> Consultant Bryce Schwanke assigned to lead 4905670 with expected tSCVR = 0.3425
#   -> Consultant Jeanne Bessler assigned to lead 4905464 with expected tSCVR = 0.3333
#   -> Consultant Rachel Brown assigned to lead 4903939 with expected tSCVR = 0.3043
#   -> Consultant April Banadonna assigned to lead 4902096 with expected tSCVR = 0.2143
#   -> Consultant Melissa Steinberg assigned to lead 4905626 with expected tSCVR = 0.25
#
# We have 5 appointments at slot 2021-02-08T18:15:00.000000000 and 7 agents to fill
# Total optimised tSCVR =  0.28996
#   -> Consultant Brian Kabat assigned to lead 4891596 with expected tSCVR = 0.4035
#   -> Consultant JoAnn Barghout assigned to lead 4898161 with expected tSCVR = 0.2581
#   -> Consultant Rachel Brown assigned to lead 4906029 with expected tSCVR = 0.2326
#   -> Consultant Melissa Steinberg assigned to lead 4906328 with expected tSCVR = 0.25
#   -> Consultant Kevin Taulman assigned to lead 4906985 with expected tSCVR = 0.3056
#
# We have 3 appointments at slot 2021-02-08T18:30:00.000000000 and 8 agents to fill
# Total optimised tSCVR =  0.3292
#   -> Consultant Amanda Newton assigned to lead 4904608 with expected tSCVR = 0.326
#   -> Consultant Brian Kabat assigned to lead 4896457 with expected tSCVR = 0.4035
#   -> Consultant JoAnn Barghout assigned to lead 4904177 with expected tSCVR = 0.2581
#
# We have 6 appointments at slot 2021-02-08T19:00:00.000000000 and 9 agents to fill
# Total optimised tSCVR =  0.29086666666666666
#   -> Consultant Amanda Newton assigned to lead 4876440 with expected tSCVR = 0.326
#   -> Consultant Brian Kabat assigned to lead 4905453 with expected tSCVR = 0.3047
#   -> Consultant Rachel Brown assigned to lead 4902785 with expected tSCVR = 0.3178
#   -> Consultant JoAnn Barghout assigned to lead 4905879 with expected tSCVR = 0.2581
#   -> Consultant Courtney Hoitt assigned to lead 4905107 with expected tSCVR = 0.233
#   -> Consultant Kevin Taulman assigned to lead 4905618 with expected tSCVR = 0.3056
#
# We have 2 appointments at slot 2021-02-08T19:15:00.000000000 and 6 agents to fill
# Total optimised tSCVR =  0.36995
#   -> Consultant Amanda Newton assigned to lead 4904633 with expected tSCVR = 0.4143
#   -> Consultant Brian Kabat assigned to lead 4901959 with expected tSCVR = 0.3256
#
# We have 2 appointments at slot 2021-02-08T19:30:00.000000000 and 8 agents to fill
# Total optimised tSCVR =  0.41315
#   -> Consultant Amanda Newton assigned to lead 4903498 with expected tSCVR = 0.4228
#   -> Consultant Brian Kabat assigned to lead 4905973 with expected tSCVR = 0.4035
#
# We have 1 appointments at slot 2021-02-08T19:45:00.000000000 and 5 agents to fill
# Total optimised tSCVR =  0.326
#   -> Consultant Amanda Newton assigned to lead 4889477 with expected tSCVR = 0.326
#
# We have 1 appointments at slot 2021-02-08T20:00:00.000000000 and 3 agents to fill
# Total optimised tSCVR =  0.3265
#   -> Consultant Amanda Newton assigned to lead 4906535 with expected tSCVR = 0.3265
#
# We have 1 appointments at slot 2021-02-08T20:15:00.000000000 and 4 agents to fill
# Total optimised tSCVR =  0.3714
#   -> Consultant Amanda Newton assigned to lead 4904673 with expected tSCVR = 0.3714
#
# We have 1 appointments at slot 2021-02-08T21:00:00.000000000 and 1 agents to fill
# Total optimised tSCVR =  0.2955
#   -> Consultant Courtney Hoitt assigned to lead 4906096 with expected tSCVR = 0.2955
#
# We have 1 appointments at slot 2021-02-08T21:45:00.000000000 and 1 agents to fill
# Total optimised tSCVR =  0.16670000000000001
#   -> Consultant Courtney Hoitt assigned to lead 4904925 with expected tSCVR = 0.1667

# %%
df_final_assignments = pd.merge(df_opt_assignment, df_final_assigned[['mgr_name','user_id']].drop_duplicates(), on='mgr_name', how='left')
df_final_assignments = pd.merge(df_final_assignments, df_categories, left_on = 'assigned_contact', right_on = 'contact_id', how='left')
df_final_assignments['action'] = 'todo reassign'
df_final_assignments['original_id'] = np.nan
df_unassigned_leads = df_categories[df_categories.contact_id.isin(unassigned_leads)]

# %%
df_final_assignments
# Out:
#                interval           mgr_name  assigned_contact     user_id  \
# 0   2021-02-08 07:15:00        Brian Kabat           4903994  1039556639
# 1   2021-02-08 07:15:00   Kimberly Murdock           4904151  1038505513
# 2   2021-02-08 07:45:00        Brian Kabat           4453403  1039556639
# 3   2021-02-08 07:45:00   Kimberly Murdock           4905551  1038505513
# 4   2021-02-08 08:00:00  Rosidalma Houston           4902212  1043792699
# ..                  ...                ...               ...         ...
# 219 2021-02-08 19:45:00      Amanda Newton           4889477  1044266872
# 220 2021-02-08 20:00:00      Amanda Newton           4906535  1044266872
# 221 2021-02-08 20:15:00      Amanda Newton           4904673  1044266872
# 222 2021-02-08 21:00:00     Courtney Hoitt           4906096  1042447037
# 223 2021-02-08 21:45:00     Courtney Hoitt           4904925  1042447037
#
#      contact_id contact_created_date first_interaction_type  \
# 0       4903994  2021-02-07 14:07:10           LFS callback
# 1       4904151  2021-02-07 14:46:28           LFS callback
# 2       4453403  2020-11-10 09:20:16           LFS callback
# 3       4905551  2021-02-07 20:42:04           LFS callback
# 4       4902212  2021-02-07 02:17:38           LFS callback
# ..          ...                  ...                    ...
# 219     4889477  2021-02-04 14:17:05           LFS callback
# 220     4906535  2021-02-08 01:07:08           LFS callback
# 221     4904673  2021-02-07 17:16:17           LFS callback
# 222     4906096  2021-02-07 22:43:18           LFS callback
# 223     4904925  2021-02-07 18:20:02           LFS callback
#
#           subject_group  callback_todo_id adword_subject_type_2  \
# 0    Other Foreign Lang          38823141                 Class
# 1    Other Foreign Lang          38823912                Course
# 2    Other Foreign Lang          38827380                 Class
# 3             Grade K-6          38828655                 Tutor
# 4    Other Foreign Lang          38809758                 Tutor
# ..                  ...               ...                   ...
# 219         HS/Col STEM          38781439                 Tutor
# 220  Other Foreign Lang          38830588                 Tutor
# 221             Spanish          38827167                 Tutor
# 222             Grad TP          38829689                 Study
# 223  Other Foreign Lang          38827182                 Class
#
#        callback_at_time tags_name         action  original_id
# 0   2021-02-08 07:15:00   GW main  todo reassign          NaN
# 1   2021-02-08 07:15:00   GW main  todo reassign          NaN
# 2   2021-02-08 07:45:00   GW main  todo reassign          NaN
# 3   2021-02-08 07:45:00   GW main  todo reassign          NaN
# 4   2021-02-08 08:00:00   GW main  todo reassign          NaN
# ..                  ...       ...            ...          ...
# 219 2021-02-08 19:45:00        EW  todo reassign          NaN
# 220 2021-02-08 20:00:00   GW main  todo reassign          NaN
# 221 2021-02-08 20:15:00   GW main  todo reassign          NaN
# 222 2021-02-08 21:00:00   GW main  todo reassign          NaN
# 223 2021-02-08 21:45:00   GW main  todo reassign          NaN
#
# [224 rows x 14 columns]

# %%
timestamp_str = dtt.datetime.now().strftime("%Y-%m-%dT%H%M%S")
filename = 'FlutterShy_assignment_'+ timestamp_str +'.csv'
df_final_assignments[['callback_todo_id','action','user_id','original_id','mgr_name']].to_csv(filename, index=False)

# %%
writer = pd.ExcelWriter('FlutterShy_Collated_' + timestamp_str + '.xlsx', engine='xlsxwriter')
# Write each dataframe to a different worksheet.
df_final_assignments.to_excel(writer, sheet_name='Assignment Sheet')
df_categories.to_excel(writer, sheet_name='Callbacks list')
df_rep_tscvr.to_excel(writer, sheet_name='Rep tSCVR')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
